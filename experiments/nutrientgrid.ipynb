# %%
import matplotlib.pyplot as plt
import numpy as np

x_max = 400
y_max = 400
z_max = 50

# %%
rng = np.random.default_rng(42)
values = (rng.random((400, 400, 50), dtype=np.float64) * 0.005)

x = range(x_max)
y = range(y_max)
z = range(z_max)

X, Y, Z = np.meshgrid(x, y, z)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X, Y, Z, c=values, cmap='BuPu', s=1, marker='s', vmin=0, vmax=0.05)

ax.set_aspect('equal')

ax.set_xlim(0, x_max)
ax.set_ylim(0, y_max)
ax.set_zlim(0, z_max)

ax.set_xlabel("X", labelpad=10)
ax.set_ylabel("Y", labelpad=10)
ax.set_zticks([])

ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.set_facecolor("white")

fig.colorbar(scatter, ax=ax)

plt.show()

# %%
values = np.load('../sosi/hpc/36/nutrient_grid_end_.npy')

x = range(x_max)
y = range(y_max)
z = range(z_max)

X, Y, Z = np.meshgrid(x, y, z)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X, Y, Z, c=values, cmap='BuPu', s=1, marker='s', vmin=0, vmax=0.05)

ax.set_aspect('equal')

ax.set_xlim(0, x_max)
ax.set_ylim(0, y_max)
ax.set_zlim(0, z_max)

ax.set_xlabel("X", labelpad=10)
ax.set_ylabel("Y", labelpad=10)
ax.set_zticks([])

ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.set_facecolor("white")

fig.colorbar(scatter, ax=ax)

plt.show()

# %%
values = np.load('../sosi/hpc/36/nutrient_grid_end_.npy')

# %%
values.flatten().sum()/len(values.flatten())
# Out:
# 0.002499220163990608
