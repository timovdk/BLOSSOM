# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
from sklearn import metrics

filenames = ['agent_log', 'agent_log_1','agent_log_2','agent_log_3', 'agent_log_4', 'agent_log_11', 'agent_log_12', 'agent_log_13', 'agent_log_14', 'agent_log_15', 'agent_log_16', 'agent_log_17', 'agent_log_18', 'agent_log_19', 'agent_log_20', 'agent_log_21', 'agent_log_22', 'agent_log_23', 'agent_log_24', 'agent_log_25', 'agent_log_26', 'agent_log_27', 'agent_log_28', 'agent_log_29', 'agent_log_30']

x_max = 400
y_max = 400
z_max = 50

SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.style.use("seaborn-v0_8-whitegrid")

# %%
import json
# 0.2
initial_net = nx.node_link_graph(json.loads('{"directed": false, "multigraph": false, "graph": {}, "nodes": [{"id": 0}, {"id": 1}, {"id": 2}, {"id": 3}, {"id": 4}, {"id": 5}, {"id": 6}, {"id": 7}, {"id": 8}, {"id": 9}, {"id": 10}, {"id": 11}], "links": [{"weight": 0.5826312884833548, "source": 0, "target": 4}, {"weight": 0.6148356427539814, "source": 0, "target": 7}, {"weight": 0.7306576990838498, "source": 1, "target": 2}, {"weight": 0.9003900420385831, "source": 1, "target": 6}, {"weight": -0.638579754693958, "source": 3, "target": 4}, {"weight": -0.27796656418881527, "source": 3, "target": 9}, {"weight": 0.46123412849139406, "source": 4, "target": 5}, {"weight": 0.6068144174853789, "source": 5, "target": 9}, {"weight": 0.5112680070896285, "source": 5, "target": 10}, {"weight": 0.42525572507758125, "source": 6, "target": 10}]}'))
# 0.25
#initial_net = nx.node_link_graph(json.loads('{"directed": false, "multigraph": false, "graph": {}, "nodes": [{"id": 0}, {"id": 1}, {"id": 2}, {"id": 3}, {"id": 4}, {"id": 5}, {"id": 6}, {"id": 7}, {"id": 8}, {"id": 9}, {"id": 10}, {"id": 11}], "links": [{"weight": -0.32406617852307235, "source": 0, "target": 2}, {"weight": 0.7674507370630747, "source": 0, "target": 11}, {"weight": -0.3678157801657671, "source": 1, "target": 5}, {"weight": -0.6113084319958945, "source": 1, "target": 10}, {"weight": 0.6735930396533623, "source": 2, "target": 3}, {"weight": 0.4957544613997652, "source": 3, "target": 4}, {"weight": -0.5093165937801768, "source": 4, "target": 7}, {"weight": -0.24377914772112863, "source": 4, "target": 8}, {"weight": -0.3891347231209051, "source": 5, "target": 6}, {"weight": -0.3671607233883024, "source": 5, "target": 8}, {"weight": 0.5827915799403651, "source": 6, "target": 7}, {"weight": -0.3854345909962471, "source": 8, "target": 11}, {"weight": 0.6131581562960552, "source": 9, "target": 10}]}'))
# 0.3
#initial_net = nx.node_link_graph(json.loads('{"directed": false, "multigraph": false, "graph": {}, "nodes": [{"id": 0}, {"id": 1}, {"id": 2}, {"id": 3}, {"id": 4}, {"id": 5}, {"id": 6}, {"id": 7}, {"id": 8}, {"id": 9}, {"id": 10}, {"id": 11}], "links": [{"weight": -0.4109884842549893, "source": 0, "target": 2}, {"weight": -0.6387307685616226, "source": 0, "target": 3}, {"weight": -0.4188281788431216, "source": 0, "target": 4}, {"weight": 0.550937882540557, "source": 0, "target": 8}, {"weight": -0.40628807899863245,
# 0.5
#initial_net = nx.node_link_graph(json.loads('{"directed": false, "multigraph": false, "graph": {}, "nodes": [{"id": 0}, {"id": 1}, {"id": 2}, {"id": 3}, {"id": 4}, {"id": 5}, {"id": 6}, {"id": 7}, {"id": 8}, {"id": 9}, {"id": 10}, {"id": 11}], "links": [{"weight": -0.2183337421259547, "source": 0, "target": 1}, {"weight": -0.49126280507745607, "source": 0, "target": 3}, {"weight": 0.46122648902262026, "source": 0, "target": 5}, {"weight": 0.6504106026697125, "source": 0, "target": 7}, {"weight": 0.31191439598587567, "source": 0, "target": 8}, {"weight": -0.21278552951051022, "source": 0, "target": 10}, {"weight": 0.682816631888224, "source": 1, "target": 2}, {"weight": 0.7635354751118769, "source": 1, "target": 4}, {"weight": 0.36060526428664974, "source": 1, "target": 10}, {"weight": -0.40475817804268077, "source": 2, "target": 3}, {"weight": 0.7185505928103799, "source": 2, "target": 4}, {"weight": 0.3339817800217799, "source": 2, "target": 7}, {"weight": -0.5573930070098837, "source": 2, "target": 10}, {"weight": 0.6172158489820869, "source": 3, "target": 6}, {"weight": -0.5983571003546093, "source": 3, "target": 7}, {"weight": -0.6934122562641605, "source": 3, "target": 8}, {"weight": 0.7452690481884369, "source": 3, "target": 11}, {"weight": 0.2751795712903666, "source": 4, "target": 5}, {"weight": 0.4549318014352687, "source": 4, "target": 7}, {"weight": 0.5714305314880215, "source": 4, "target": 8}, {"weight": 0.6786629743321152, "source": 4, "target": 10}, {"weight": -0.6055497503977925, "source": 4, "target": 11}, {"weight": -0.7408935485251531, "source": 5, "target": 6}, {"weight": 0.15226154456646668, "source": 5, "target": 10}, {"weight": 0.5317440416773723, "source": 6, "target": 7}, {"weight": 0.8380066366725752, "source": 6, "target": 10}, {"weight": -0.5995496980033568, "source": 6, "target": 11}, {"weight": 0.41844372754609355, "source": 7, "target": 8}, {"weight": 0.7394227548330733, "source": 7, "target": 10}, {"weight": -0.4290783660575242, "source": 8, "target": 9}, {"weight": 0.5221436404793517, "source": 9, "target": 10}, {"weight": 0.2465592328968837, "source": 9, "target": 11}, {"weight": 0.19883937223332598, "source": 10, "target": 11}]}'))


initial_matrix = nx.adjacency_matrix(initial_net).todense()

# %%
def pearson_cooccurrence(abundance_data, threshold=0):
    # Initialize a graph
    G = nx.Graph()
    G.add_nodes_from(range(12))

    # Calculate the Pearson correlation coefficient matrix
    pearson_matrix = np.corrcoef(abundance_data, rowvar=False)
    
    pearson_matrix[np.isnan(pearson_matrix)] = 0

    # Get the number of entities
    num_entities = len(abundance_data[0])

    # Iterate through the Pearson correlation matrix to create co-occurrence edges
    for i in range(num_entities):
        for j in range(i + 1, num_entities):
            # Check if the correlation coefficient exceeds the threshold
            if (pearson_matrix[i][j] > threshold):
                G.add_edge(i, j, weight=pearson_matrix[i][j])

    return G, pearson_matrix

# %%
def retrieve_ids_per_sample_von_neumann(points, data, r, d):
    samples =  [ [] for _ in range(len(points)) ]
    for ind, row in data.iterrows():
        for index, point in enumerate(points):
            x1, y1 = point
            x2 = row.x
            y2 = row.y
            z2 = row.z

            if (z2 <= d) and ((abs(x1 - x2) + abs(y1 - y2)) <= r):
                samples[index].append(ind)
    return samples

def systematic_regular(no_of_samples, x, y):
    # Calculate the dimensions of the regular grid
    rows = int(np.sqrt(no_of_samples))
    cols = int(np.ceil(no_of_samples / rows))

    # Calculate the padding to ensure points are equally spaced
    padding_x = (x - (rows - 1)) // rows
    padding_y = (y - (cols - 1)) // cols

    # Initialize points list
    points = []

    # Select equally spaced points with padding
    for i in range(rows):
        for j in range(cols):
            points.append((int((i * (padding_x + 1)) + ((padding_x + 1)/2)), int((j * (padding_y + 1) + ((padding_y + 1)/2)))))

    return points[:no_of_samples]

def systematic_random(no_of_samples, x, y):
    # Calculate the dimensions of the regular grid
    rows = int(np.sqrt(no_of_samples))
    cols = int(np.ceil(no_of_samples / rows))

    # Calculate the padding to ensure points are equally spaced
    padding_x = (x - (rows - 1)) // rows
    padding_y = (y - (cols - 1)) // cols

    # Initialize points list
    points = []
    x_range = range(int(-(padding_x + 1)/2), int((padding_x + 1)/2))
    y_range = range(int(-(padding_y + 1)/2), int((padding_y + 1)/2))

    # Select equally spaced points with padding
    for i in range(rows):
        for j in range(cols):
            x_offset = np.random.choice(x_range)
            y_offset = np.random.choice(y_range)
            points.append((int((i * (padding_x + 1)) + ((padding_x + 1)/2) + x_offset), int((j * (padding_y + 1) + ((padding_y + 1)/2)) + y_offset)))

    return points[:no_of_samples]

def default_random(no_of_samples, x, y):
    # Initialize points list
    points = []
    x_range = range(x)
    y_range = range(y)

    # Select equally spaced points with padding
    for _ in range(no_of_samples):
        x_coord = np.random.choice(x_range)
        y_coord = np.random.choice(y_range)
        points.append((x_coord, y_coord))

    return points[:no_of_samples]

def wageningen_w():
    return [(50, 50), (50, 150), (50, 250), (50, 350), (125, 150), (175, 250), (275, 150), (225, 250), (350, 50), (350, 150), (350, 250), (350, 350)]

# %%
x_max = 400
y_max = 400
z_max = 50
no_of_samples = 16
r = 6
d = 50
    
sample_site_counts = []

for filename in filenames:
    df = pd.read_csv("output/" + filename + ".csv")
    df_last = df[df["tick"] == df["tick"].max()]
    
    df_last = df_last.reset_index(drop=True)

    selected_points = systematic_regular(no_of_samples, x_max, y_max)
    #selected_points = systematic_random(no_of_samples, x_max, y_max)
    #selected_points = default_random(no_of_samples, x_max, y_max)
    #selected_points = wageningen_w()
    samples = retrieve_ids_per_sample_von_neumann(selected_points, df_last, r, d)

    for sample_site in samples:
        df2 = df_last.iloc[sample_site]
        count = df2['type'].value_counts().reindex(range(len(df["type"].unique())), fill_value=0)
        sample_site_counts.append([val for _, val in count.items()])
    
 
pearson_net, pearson = pearson_cooccurrence(sample_site_counts, 0)

for filename in filenames:
    
    gt_matrix = np.load('counts_per_type_' + filename + '.npy')
    gt_pearson_net, gt_pearson = pearson_cooccurrence(gt_matrix, 0)

    print("Initial co-occurrence <-> Ground truth")
    print("MAE: ", metrics.mean_absolute_error(initial_matrix, gt_pearson))
    print("MaxE: ", metrics.max_error(initial_matrix.flatten(), gt_pearson.flatten()))
    print("MdAE: ", metrics.median_absolute_error(initial_matrix, gt_pearson))
    print("R2: ", metrics.r2_score(initial_matrix, gt_pearson))
    print("EV: ", metrics.explained_variance_score(initial_matrix, gt_pearson))
    print("\nGround truth <-> Sampling")
    print("MAE: ", metrics.mean_absolute_error(gt_pearson, pearson))
    print("MaxE: ", metrics.max_error(gt_pearson.flatten(), pearson.flatten()))
    print("MdAE: ", metrics.median_absolute_error(gt_pearson, pearson))
    print("R2: ", metrics.r2_score(gt_pearson, pearson))
    print("EV: ", metrics.explained_variance_score(gt_pearson, pearson))
    print("\nInitial co-occurrence <-> Sampling")
    print("MAE: ", metrics.mean_absolute_error(initial_matrix, pearson))
    print("MaxE: ", metrics.max_error(initial_matrix.flatten(), pearson.flatten()))
    print("MdAE: ", metrics.median_absolute_error(initial_matrix, pearson))
    print("R2: ", metrics.r2_score(initial_matrix, pearson))
    print("EV: ", metrics.explained_variance_score(initial_matrix, pearson))
# Out:
# Initial co-occurrence <-> Ground truth
# MAE:  0.1796482073852108
# MaxE:  1.0
# MdAE:  0.06948728925000154
# R2:  -1.325363329818923
# EV:  -1.2720840744747035
#
# Ground truth <-> Sampling
# MAE:  0.11052461394009046
# MaxE:  1.0
# MdAE:  0.05024208643810383
# R2:  0.42247198809796854
# EV:  0.4353310480784675
#
# Initial co-occurrence <-> Sampling
# MAE:  0.19439883372188504
# MaxE:  1.0
# MdAE:  0.037956004003971554
# R2:  -1.7368314778130791
# EV:  -1.6567180079725958
# Initial co-occurrence <-> Ground truth
# MAE:  0.31088754723730705
# MaxE:  1.0812245294512515
# MdAE:  0.17933011677969088
# R2:  -3.3031525991653226
# EV:  -3.03195718601172
#
# Ground truth <-> Sampling
# MAE:  0.2118358320160695
# MaxE:  1.0675137298180637
# MdAE:  0.14234677017595998
# R2:  0.40156128696990984
# EV:  0.4509670796946526
#
# Initial co-occurrence <-> Sampling
# MAE:  0.19439883372188504
# MaxE:  1.0
# MdAE:  0.037956004003971554
# R2:  -1.7368314778130791
# EV:  -1.6567180079725958
# Initial co-occurrence <-> Ground truth
# MAE:  0.32028169897702913
# MaxE:  1.183232754513202
# MdAE:  0.20974137439921473
# R2:  -2.8783515871551075
# EV:  -2.8097016992507062
#
# Ground truth <-> Sampling
# MAE:  0.1983446550404738
# MaxE:  1.0
# MdAE:  0.1585115440300716
# R2:  0.4652106464266928
# EV:  0.5056439876160338
#
# Initial co-occurrence <-> Sampling
# MAE:  0.19439883372188504
# MaxE:  1.0
# MdAE:  0.037956004003971554
# R2:  -1.7368314778130791
# EV:  -1.6567180079725958
# Initial co-occurrence <-> Ground truth
# MAE:  0.2813258581471852
# MaxE:  1.0
# MdAE:  0.18653092159561557
# R2:  -2.8946556935359227
# EV:  -2.6855013650569277
#
# Ground truth <-> Sampling
# MAE:  0.1785267717968498
# MaxE:  1.0
# MdAE:  0.128981104420938
# R2:  0.44415005731918794
# EV:  0.4658417238200366
#
# Initial co-occurrence <-> Sampling
# MAE:  0.19439883372188504
# MaxE:  1.0
# MdAE:  0.037956004003971554
# R2:  -1.7368314778130791
# EV:  -1.6567180079725958
# Initial co-occurrence <-> Ground truth
# MAE:  0.2829882822908763
# MaxE:  1.2240663977713475
# MdAE:  0.1070831278503518
# R2:  -3.11839083561572
# EV:  -2.746618473908191
#
# Ground truth <-> Sampling
# MAE:  0.16100087853009717
# MaxE:  1.0325332586154214
# MdAE:  0.08575448944938212
# R2:  0.3991748293501589
# EV:  0.43287200058941727
#
# Initial co-occurrence <-> Sampling
# MAE:  0.19439883372188504
# MaxE:  1.0
# MdAE:  0.037956004003971554
# R2:  -1.7368314778130791
# EV:  -1.6567180079725958
# Initial co-occurrence <-> Ground truth
# MAE:  0.26084050132790143
# MaxE:  1.0
# MdAE:  0.14188187368840502
# R2:  -2.0980175488606876
# EV:  -1.9322736669105776
#
# Ground truth <-> Sampling
# MAE:  0.1689102106506982
# MaxE:  1.0204832003919533
# MdAE:  0.08517482599793373
# R2:  0.3426625604043241
# EV:  0.3907111758925211
#
# Initial co-occurrence <-> Sampling
# MAE:  0.19439883372188504
# MaxE:  1.0
# MdAE:  0.037956004003971554
# R2:  -1.7368314778130791
# EV:  -1.6567180079725958
# Initial co-occurrence <-> Ground truth
# MAE:  0
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
data = []
for filename in filenames:
    df = pd.read_csv("output/" + filename + ".csv")
    df_last = df[df["tick"] == df["tick"].max()]
    
    df_last = df_last.reset_index(drop=True)
    
    x_max = 400
    y_max = 400
    z_max = 50

    no_of_samples = 16
    r = 6
    d = 50

    selected_points = systematic_regular(no_of_samples, x_max, y_max)
    #selected_points = systematic_random(no_of_samples, x_max, y_max)
    #selected_points = default_random(no_of_samples, x_max, y_max)
    #selected_points = wageningen_w()
    samples = retrieve_ids_per_sample_von_neumann(selected_points, df_last, r, d)
    
    sample_site_counts = []
    for sample_site in samples:
        df2 = df_last.iloc[sample_site]
        count = df2['type'].value_counts().reindex(range(len(df["type"].unique())), fill_value=0)
        sample_site_counts.append([val for _, val in count.items()])
    
    pearson_net, pearson = pearson_cooccurrence(sample_site_counts, 0)
    
    gt_matrix = np.load('counts_per_type_' + filename + '.npy')
    
    gt_pearson_net, gt_pearson = pearson_cooccurrence(gt_matrix, 0)
    
    print('\n' + filename)
    print("Initial co-occurrence <-> Ground truth")
    print("MAE: ", metrics.mean_absolute_error(initial_matrix, gt_pearson))
    print("MaxE: ", metrics.max_error(initial_matrix.flatten(), gt_pearson.flatten()))
    print("MdAE: ", metrics.median_absolute_error(initial_matrix, gt_pearson))
    print("R2: ", metrics.r2_score(initial_matrix, gt_pearson))
    print("EV: ", metrics.explained_variance_score(initial_matrix, gt_pearson))
    print("\nGround truth <-> Sampling")
    print("MAE: ", metrics.mean_absolute_error(gt_pearson, pearson))
    print("MaxE: ", metrics.max_error(gt_pearson.flatten(), pearson.flatten()))
    print("MdAE: ", metrics.median_absolute_error(gt_pearson, pearson))
    print("R2: ", metrics.r2_score(gt_pearson, pearson))
    print("EV: ", metrics.explained_variance_score(gt_pearson, pearson))
    print("\nInitial co-occurrence <-> Sampling")
    print("MAE: ", metrics.mean_absolute_error(initial_matrix, pearson))
    print("MaxE: ", metrics.max_error(initial_matrix.flatten(), pearson.flatten()))
    print("MdAE: ", metrics.median_absolute_error(initial_matrix, pearson))
    print("R2: ", metrics.r2_score(initial_matrix, pearson))
    print("EV: ", metrics.explained_variance_score(initial_matrix, pearson))
# Out:
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log
# Initial co-occurrence <-> Ground truth
# MAE:  0.1796482073852108
# MaxE:  1.0
# MdAE:  0.06948728925000154
# R2:  -1.325363329818923
# EV:  -1.2720840744747035
#
# Ground truth <-> Sampling
# MAE:  0.07687221846656249
# MaxE:  1.0
# MdAE:  0.03698920436461008
# R2:  0.6110826980866457
# EV:  0.627105645744527
#
# Initial co-occurrence <-> Sampling
# MAE:  0.16431813308134866
# MaxE:  1.0
# MdAE:  0.057789665671564135
# R2:  -1.1794505483162168
# EV:  -1.0840965334472041
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_1
# Initial co-occurrence <-> Ground truth
# MAE:  0.31088754723730705
# MaxE:  1.0812245294512515
# MdAE:  0.17933011677969088
# R2:  -3.3031525991653226
# EV:  -3.03195718601172
#
# Ground truth <-> Sampling
# MAE:  0.21788392034763773
# MaxE:  1.0272590619157698
# MdAE:  0.13198802607260135
# R2:  0.33789250233023044
# EV:  0.4019199940957732
#
# Initial co-occurrence <-> Sampling
# MAE:  0.20726427712504922
# MaxE:  1.0
# MdAE:  0.0777172475238085
# R2:  -1.5932086530992977
# EV:  -1.5272017935312796
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_2
# Initial co-occurrence <-> Ground truth
# MAE:  0.32028169897702913
# MaxE:  1.183232754513202
# MdAE:  0.20974137439921473
# R2:  -2.8783515871551075
# EV:  -2.8097016992507062
#
# Ground truth <-> Sampling
# MAE:  0.20326202422886608
# MaxE:  1.0
# MdAE:  0.1274397349264545
# R2:  0.32150580315865934
# EV:  0.36259936743103643
#
# Initial co-occurrence <-> Sampling
# MAE:  0.2051579676960645
# MaxE:  1.0
# MdAE:  0.07252925849499174
# R2:  -1.649129007107699
# EV:  -1.5537289530780114
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_3
# Initial co-occurrence <-> Ground truth
# MAE:  0.2813258581471852
# MaxE:  1.0
# MdAE:  0.18653092159561557
# R2:  -2.8946556935359227
# EV:  -2.6855013650569277
#
# Ground truth <-> Sampling
# MAE:  0.19196697322565948
# MaxE:  1.1740776559556978
# MdAE:  0.11773603129769844
# R2:  0.21846230080532278
# EV:  0.26234687863876355
#
# Initial co-occurrence <-> Sampling
# MAE:  0.2083447240094574
# MaxE:  1.0
# MdAE:  0.07194126519765882
# R2:  -1.6164122823257878
# EV:  -1.5487272601671398
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_4
# Initial co-occurrence <-> Ground truth
# MAE:  0.2829882822908763
# MaxE:  1.2240663977713475
# MdAE:  0.1070831278503518
# R2:  -3.11839083561572
# EV:  -2.746618473908191
#
# Ground truth <-> Sampling
# MAE:  0.2079312500533198
# MaxE:  1.147608911099847
# MdAE:  0.09604909987549604
# R2:  0.08140543590716509
# EV:  0.12786085703430117
#
# Initial co-occurrence <-> Sampling
# MAE:  0.2091392543630215
# MaxE:  1.0
# MdAE:  0.07867920567018084
# R2:  -1.7760441461931549
# EV:  -1.6863152537935804
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_11
# Initial co-occurrence <-> Ground truth
# MAE:  0.26084050132790143
# MaxE:  1.0
# MdAE:  0.14188187368840502
# R2:  -2.0980175488606876
# EV:  -1.9322736669105776
#
# Ground truth <-> Sampling
# MAE:  0.18299513910286216
# MaxE:  1.0
# MdAE:  0.10650877297969019
# R2:  0.2948560513015499
# EV:  0.37285691162995827
#
# Initial co-occurrence <-> Sampling
# MAE:  0.1655957287063397
# MaxE:  1.0
# MdAE:  0.055602921216596296
# R2:  -1.0320890848560573
# EV:  -0.9067273307371636
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_12
# Initial co-occurrence <-> Ground truth
# MAE:  0.36505353355594955
# MaxE:  1.0240150235082786
# MdAE:  0.2591679643471916
# R2:  -3.8896316168240683
# EV:  -3.576040502156563
#
# Ground truth <-> Sampling
# MAE:  0.301487160146664
# MaxE:  1.2893236173200233
# MdAE:  0.17513464764303643
# R2:  -0.04611405879367484
# EV:  0.06487729937272123
#
# Initial co-occurrence <-> Sampling
# MAE:  0.2463490190248785
# MaxE:  1.0
# MdAE:  0.10101328497504301
# R2:  -1.8651387381498212
# EV:  -1.7105929959972206
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_13
# Initial co-occurrence <-> Ground truth
# MAE:  0.3313852554302691
# MaxE:  1.0847922214594243
# MdAE:  0.24475419115269517
# R2:  -2.784969475512583
# EV:  -2.5074980581341824
#
# Ground truth <-> Sampling
# MAE:  0.2414825775551327
# MaxE:  1.0832526819878932
# MdAE:  0.15100136431279942
# R2:  0.1760375393087322
# EV:  0.27179209865354736
#
# Initial co-occurrence <-> Sampling
# MAE:  0.25388989108310633
# MaxE:  1.0
# MdAE:  0.101026500980662
# R2:  -2.260013065867843
# EV:  -2.0240701102456486
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_14
# Initial co-occurrence <-> Ground truth
# MAE:  0.1953373228744785
# MaxE:  1.0
# MdAE:  0.10244013344872092
# R2:  -1.24530912048132
# EV:  -1.092306328097163
#
# Ground truth <-> Sampling
# MAE:  0.13348970906911717
# MaxE:  1.0
# MdAE:  0.049411739466357275
# R2:  0.3810104018951818
# EV:  0.44787801483201745
#
# Initial co-occurrence <-> Sampling
# MAE:  0.16548272835989664
# MaxE:  1.0
# MdAE:  0.052584505368837305
# R2:  -1.3358935652085648
# EV:  -1.2661222630552935
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_15
# Initial co-occurrence <-> Ground truth
# MAE:  0.2795012839688618
# MaxE:  1.0
# MdAE:  0.1498025688124414
# R2:  -2.7382555904107515
# EV:  -2.4141727057855067
#
# Ground truth <-> Sampling
# MAE:  0.2096831212931406
# MaxE:  1.175976538025624
# MdAE:  0.0808375083280866
# R2:  0.1124455823228193
# EV:  0.17556653300119404
#
# Initial co-occurrence <-> Sampling
# MAE:  0.18470323841200617
# MaxE:  1.0
# MdAE:  0.05400248175886294
# R2:  -1.4353400871238025
# EV:  -1.3480128622505265
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_16
# Initial co-occurrence <-> Ground truth
# MAE:  0.3059364752961851
# MaxE:  1.0
# MdAE:  0.18904411795474318
# R2:  -2.6864764242034673
# EV:  -2.50040277308804
#
# Ground truth <-> Sampling
# MAE:  0.25434513240525664
# MaxE:  1.1875795786366736
# MdAE:  0.09483593597981925
# R2:  -0.17473448869319044
# EV:  -0.08821008890069197
#
# Initial co-occurrence <-> Sampling
# MAE:  0.23078730866680197
# MaxE:  1.0
# MdAE:  0.07354038159710531
# R2:  -2.041898977452484
# EV:  -1.9288341201063297
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_17
# Initial co-occurrence <-> Ground truth
# MAE:  0.2067792003898078
# MaxE:  1.0321058844820412
# MdAE:  0.09468857984939323
# R2:  -1.6961993281966714
# EV:  -1.5891229432723624
#
# Ground truth <-> Sampling
# MAE:  0.1806575309327821
# MaxE:  1.0
# MdAE:  0.09449339642509397
# R2:  0.2249358107781858
# EV:  0.25680229122530185
#
# Initial co-occurrence <-> Sampling
# MAE:  0.22668173553693338
# MaxE:  1.0
# MdAE:  0.07307348782294412
# R2:  -2.0224704579645336
# EV:  -1.9551631509102407
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_18
# Initial co-occurrence <-> Ground truth
# MAE:  0.19095756299368247
# MaxE:  1.0
# MdAE:  0.07925577658410483
# R2:  -1.0664402377695834
# EV:  -0.9608042839901403
#
# Ground truth <-> Sampling
# MAE:  0.1860366652437807
# MaxE:  1.0
# MdAE:  0.10328326762915642
# R2:  0.21535794000147113
# EV:  0.25151682121906044
#
# Initial co-occurrence <-> Sampling
# MAE:  0.21758395467640293
# MaxE:  1.0
# MdAE:  0.08352857609518995
# R2:  -2.022399332326725
# EV:  -1.8644652819073422
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_19
# Initial co-occurrence <-> Ground truth
# MAE:  0.24050566958363892
# MaxE:  1.158588931785744
# MdAE:  0.12294653431996039
# R2:  -1.8221170871765626
# EV:  -1.617466389058693
#
# Ground truth <-> Sampling
# MAE:  0.17857548759653286
# MaxE:  1.0894353608437874
# MdAE:  0.07294765677769342
# R2:  0.2996017285861883
# EV:  0.35598035769336794
#
# Initial co-occurrence <-> Sampling
# MAE:  0.1896349401881988
# MaxE:  1.0
# MdAE:  0.05475454106956031
# R2:  -1.5367011965711594
# EV:  -1.4547979475260984
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_20
# Initial co-occurrence <-> Ground truth
# MAE:  0.2466665165147551
# MaxE:  1.0
# MdAE:  0.14088836139626926
# R2:  -2.1632294089891198
# EV:  -1.887807121885002
#
# Ground truth <-> Sampling
# MAE:  0.16296105002692132
# MaxE:  1.0678134930655205
# MdAE:  0.07465787221839033
# R2:  0.2733295781547513
# EV:  0.30310103010740547
#
# Initial co-occurrence <-> Sampling
# MAE:  0.24607998392229424
# MaxE:  1.0
# MdAE:  0.09976221205237445
# R2:  -1.8509314426765424
# EV:  -1.7218056356972777
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_21
# Initial co-occurrence <-> Ground truth
# MAE:  0.35563335262130863
# MaxE:  1.0938791675791002
# MdAE:  0.24629129035655947
# R2:  -3.8459075208936753
# EV:  -3.596999645773662
#
# Ground truth <-> Sampling
# MAE:  0.2328876030735825
# MaxE:  1.0
# MdAE:  0.1353465730862329
# R2:  0.22871331317246604
# EV:  0.29445166257683436
#
# Initial co-occurrence <-> Sampling
# MAE:  0.21745977860476884
# MaxE:  1.0
# MdAE:  0.09726681302651226
# R2:  -1.9586435301354588
# EV:  -1.869914539483475
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_22
# Initial co-occurrence <-> Ground truth
# MAE:  0.20547211480970265
# MaxE:  1.0
# MdAE:  0.08576315204764184
# R2:  -1.6011933333535489
# EV:  -1.4735662316737974
#
# Ground truth <-> Sampling
# MAE:  0.15645709480535855
# MaxE:  1.0470008208123829
# MdAE:  0.06968692876073984
# R2:  0.26503253947514865
# EV:  0.3140160226908425
#
# Initial co-occurrence <-> Sampling
# MAE:  0.22058820397335763
# MaxE:  1.0
# MdAE:  0.10428405945057924
# R2:  -1.8134670648533635
# EV:  -1.7764615991436417
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_23
# Initial co-occurrence <-> Ground truth
# MAE:  0.38005659701824906
# MaxE:  1.049406125214787
# MdAE:  0.18055348297218551
# R2:  -4.532043292225047
# EV:  -4.080079824841388
#
# Ground truth <-> Sampling
# MAE:  0.2793446352188919
# MaxE:  1.1161577017694304
# MdAE:  0.1189729982217032
# R2:  0.0774425186709537
# EV:  0.19528078459102027
#
# Initial co-occurrence <-> Sampling
# MAE:  0.16607356436349738
# MaxE:  1.0
# MdAE:  0.06405065854624425
# R2:  -1.0689665623601081
# EV:  -0.989058940566327
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_24
# Initial co-occurrence <-> Ground truth
# MAE:  0.31593244711675245
# MaxE:  1.0
# MdAE:  0.1900307389131861
# R2:  -2.660912467750688
# EV:  -2.528895392255601
#
# Ground truth <-> Sampling
# MAE:  0.23836617729442353
# MaxE:  1.1456194372858555
# MdAE:  0.11187944424496156
# R2:  -0.03842368300719617
# EV:  0.03185040737763833
#
# Initial co-occurrence <-> Sampling
# MAE:  0.25737429101385584
# MaxE:  1.0
# MdAE:  0.11748416341812375
# R2:  -2.074451715894633
# EV:  -1.8480882121645221
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_25
# Initial co-occurrence <-> Ground truth
# MAE:  0.1393206056760208
# MaxE:  1.0
# MdAE:  0.03452340186803445
# R2:  -0.6934286225511288
# EV:  -0.6012454225734375
#
# Ground truth <-> Sampling
# MAE:  0.14810741089801552
# MaxE:  1.0
# MdAE:  0.07570629109583639
# R2:  0.25507787597028375
# EV:  0.26502451480155725
#
# Initial co-occurrence <-> Sampling
# MAE:  0.2757332038903202
# MaxE:  1.3217098057579313
# MdAE:  0.09853210344853754
# R2:  -3.1404822348647414
# EV:  -3.0239463311764485
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_26
# Initial co-occurrence <-> Ground truth
# MAE:  0.2456961056571746
# MaxE:  1.0
# MdAE:  0.1241581227722764
# R2:  -2.0990336809551597
# EV:  -1.9490747839910494
#
# Ground truth <-> Sampling
# MAE:  0.24250495886124457
# MaxE:  1.2272843174062567
# MdAE:  0.09093781498150887
# R2:  -0.10748381517474853
# EV:  -0.046677492312497376
#
# Initial co-occurrence <-> Sampling
# MAE:  0.24719090762933338
# MaxE:  1.0
# MdAE:  0.0863313470295743
# R2:  -2.5209026938240178
# EV:  -2.32468817037547
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_27
# Initial co-occurrence <-> Ground truth
# MAE:  0.29292360971209136
# MaxE:  1.0
# MdAE:  0.194909104407024
# R2:  -3.379749725570598
# EV:  -2.635882607346893
#
# Ground truth <-> Sampling
# MAE:  0.2364160932571394
# MaxE:  1.0888944826263969
# MdAE:  0.16286779192603834
# R2:  0.04217531832729357
# EV:  0.22903185309153684
#
# Initial co-occurrence <-> Sampling
# MAE:  0.22297695745489646
# MaxE:  1.018735309121371
# MdAE:  0.08993695377608407
# R2:  -1.9362224963866561
# EV:  -1.850291953036705
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_28
# Initial co-occurrence <-> Ground truth
# MAE:  0.3116240151551746
# MaxE:  1.0
# MdAE:  0.2142668928872692
# R2:  -2.439725393780025
# EV:  -2.3085419182183786
#
# Ground truth <-> Sampling
# MAE:  0.25312054373370857
# MaxE:  1.1465529614694436
# MdAE:  0.13919775750120492
# R2:  -0.1967278264006064
# EV:  -0.08063494269217758
#
# Initial co-occurrence <-> Sampling
# MAE:  0.24068416643209875
# MaxE:  1.0
# MdAE:  0.09421874876685003
# R2:  -2.4666535052107217
# EV:  -2.3110261130265104
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# agent_log_29
# Initial co-occurrence <-> Ground truth
# MAE:  0.3183700866067801
# MaxE:  1.1263981666166152
# MdAE:  0.2216926925218287
# R2:  -2.343104581752423
# EV:  -2.222608296727785
#
# Ground truth <-> Sampling
# MAE:  0.19774630192401052
# MaxE:  1.1061947751288737
# MdAE:  0.12278466404208917
# R2:  0.3520423908779014
# EV:  0.40996111790245343
#
# Initial co-occurrence <-> Sampling
# MAE:  0.2525648573980672
# MaxE:  1.0
# MdAE:  0.11057361196807426
# R2:  -2.302900099542224
# EV:  -2.1271484059512558
#
# agent_log_30
# Initial co-occurrence <-> Ground truth
# MAE:  0.2241583776464837
# MaxE:  1.0
# MdAE:  0.12216778307787106
# R2:  -1.577483750768477
# EV:  -1.3742914214477204
#
# Ground truth <-> Sampling
# MAE:  0.1578346508129949
# MaxE:  1.0
# MdAE:  0.09454885758327425
# R2:  0.34579604772480016
# EV:  0.4432107865494177
#
# Initial co-occurrence <-> Sampling
# MAE:  0.21373197743675865
# MaxE:  1.0
# MdAE:  0.09106288532781705
# R2:  -1.5765996300540053
# EV:  -1.5282240101291418
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/timovdk/soil_sim/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
