# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1, figsize=(5, 5))
ax.scatter(*zip(*[(50, 50), (50, 150), (50, 250), (50, 350), (125, 150), (175, 250), (275, 150), (225, 250), (350, 50), (350, 150), (350, 250), (350, 350)]), marker='s', s=50)
ax.set_xlim(0, 400)
ax.set_ylim(0, 400)
_ = ax.set_yticks([0, 50, 100, 150, 200, 250, 300, 350, 400])

# %%
fig, ax = plt.subplots(1,1, figsize=(5, 5))
ax.scatter(*zip(*[(50, 50), (50, 150), (50, 250), (50, 350), (150, 50), (150, 150), (150, 250), (150, 350), (250, 50), (250, 150), (250, 250), (250, 350), (350, 50), (350, 150), (350, 250), (350, 350)]), marker='s', s=50)
ax.set_xlim(0, 400)
ax.set_ylim(0, 400)
_ = ax.set_yticks([0, 50, 100, 150, 200, 250, 300, 350, 400])
