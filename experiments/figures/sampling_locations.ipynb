# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1, figsize=(5, 5))
ax.scatter(*zip(*[(25, 25), (25, 75), (25, 125), (25, 175), (65, 75), (85, 125), (135, 75), (115, 125), (175, 25), (175, 75), (175, 125), (175, 175)]), marker='s', s=50)
ax.set_xlim(0, 200)
ax.set_ylim(0, 200)
ax.set_yticks([0, 50, 100, 150, 200])

# %%
fig, ax = plt.subplots(1,1, figsize=(5, 5))
ax.scatter(*zip(*[(25, 25), (25, 75), (25, 125), (25, 175), (75, 25), (75, 75), (75, 125), (75, 175), (125, 25), (125, 75), (125, 125), (125, 175), (175, 25), (175, 75), (175, 125), (175, 175)]), marker='s', s=50)
ax.set_xlim(0, 200)
ax.set_ylim(0, 200)
ax.set_yticks([0, 50, 100, 150, 200])
